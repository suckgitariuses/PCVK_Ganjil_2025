# %% [markdown]
# <a href="https://colab.research.google.com/github/suckgitariuses/PCVK_Ganjil_2025/blob/main/Modul7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **MODUL 7 - Filter Spasial Low Pass Filter, High Pass Filter, Point Detection, Line Detection, Edge Detection**

# %% [markdown]
# **1. buatlah fungsi konvolusi menggunakan algoritma yang telah dijelaskan pada bagian C, tanpa menggunakan library atau metode konvolusi dari OpenCV**

# %%
import numpy as np
import cv2
from google.colab.patches import cv2_imshow

def convolution(image, kernel, padding=0, stride=1):
    # ubah kernel agar sesuai dengan definisi dari konvolusi
    kernel = np.flipud(np.fliplr(kernel))

    # ambil dimensi citra dan kernel sebgaia parameter operasi konvolusi
    xKernShape, yKernShape = kernel.shape
    xImgShape, yImgShape = image.shape

    # hitung output berdasarkan ukuran citra dan kernel
    xOutput = int(((xImgShape - xKernShape + 2*padding) / stride) + 1)
    yOutput = int(((yImgShape - yKernShape + 2*padding) / stride) + 1)
    output = np.zeros((xOutput, yOutput))

    # tambahkan padding citra jika diperlukan
    if padding != 0:
        imagePadded = np.zeros((image.shape[0] + padding*2, image.shape[1] + padding*2))
        imagePadded[padding:-padding, padding:-padding] = image
    else:
        imagePadded = image

    # proses konvolusi citra dan kernel
    for y in range(0, yOutput):
        for x in range(0, xOutput):
            region = imagePadded[x*stride:x*stride+xKernShape, y*stride:y*stride+yKernShape]
            output[x, y] = (kernel * region).sum()

    return output

# %% [markdown]
# **2. berikut merupakan langkah-langkah yang dapat diakukan:**

# %%
# akses file dari drive
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# load image
img = cv2.imread('/content/drive/MyDrive/PCVK/Images/pantai.jpg')

# Check if image was loaded successfully
if img is None:
    print("Error: Image not loaded. Please check the file path.")
else:
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

    plt.imshow(gray, cmap='gray')
    plt.title("Grayscale Image")
    plt.axis("off")
    plt.show()

    kernel_sharpen = np.array([[0, -1, 0],
                               [-1, 5, -1],
                               [0, -1, 0]])

    output_sharpen = convolution(gray, kernel_sharpen, 1,2)
    plt.imshow(output_sharpen, cmap='gray')
    plt.title("Sharpened Image")
    plt.axis("off")
    plt.show()

# %% [markdown]
# **3. buat image filter untuk avergae fiter, low pass filter, high pass filter, dan beberapa filter berikut:**

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import math

# implementasi fungsi konvolusi manual (sesuai nomor 1)
def convolution(image, kernel, padding=0, stride=1):
    kernel = np.flipud(np.fliplr(kernel))  # flip kernel
    xKernShape, yKernShape = kernel.shape
    xImgShape, yImgShape = image.shape
    xOutput = int(((xImgShape - xKernShape + 2*padding) / stride) + 1)
    yOutput = int(((yImgShape - yKernShape + 2*padding) / stride) + 1)
    output = np.zeros((xOutput, yOutput))

    if padding != 0:
        imagePadded = np.zeros((image.shape[0] + padding*2, image.shape[1] + padding*2))
        imagePadded[padding:-padding, padding:-padding] = image
    else:
        imagePadded = image

    for y in range(0, yOutput):
        for x in range(0, xOutput):
            region = imagePadded[x*stride:x*stride+xKernShape, y*stride:y*stride+yKernShape]
            output[x, y] = (kernel * region).sum()

    return output

# load image
img = cv2.imread('/content/drive/MyDrive/PCVK/Images/pantai.jpg')
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# daftar kernel yang digunakan sesuai modul
kernels = {
    "Emboss": np.array([[-2,-1,0],
                        [-1, 1,1],
                        [ 0, 1,2]]),

    "Left Sobel Edge Detection": np.array([[ 1, 0,-1],
                                           [ 2, 0,-2],
                                           [ 1, 0,-1]]),

    "Canny Edge Detection": np.array([[-1,-1,-1],
                                      [-1, 8,-1],
                                      [-1,-1,-1]]),

    "Prewitt Edge Detection": np.array([[-1,-1,-1],
                                        [ 0, 0, 0],
                                        [ 1, 1, 1]]),

    # Gaussian Blur 5x5
    "5x5 Gaussian Blur": (1/256) * np.array([[ 1,  4,  6,  4, 1],
                                             [ 4, 16, 24, 16, 4],
                                             [ 6, 24, 36, 24, 6],
                                             [ 4, 16, 24, 16, 4],
                                             [ 1,  4,  6,  4, 1]])
}

# Gaussian 21x21 dengan fungsi OpenCV
kernel_size = 21
sigma = math.sqrt(kernel_size)
gaussian_kernel = cv2.getGaussianKernel(kernel_size, sigma)
kernels["21x21 Gaussian Blur"] = gaussian_kernel @ gaussian_kernel.T

kernel_sharpen = np.array([[0, -1, 0],
                            [-1, 5, -1],
                            [0, -1, 0]])

output_sharpen = convolution(gray, kernel_sharpen, 1,2)
plt.imshow(output_sharpen, cmap='gray')
plt.title("Sharpened Image")
plt.axis("off")
plt.show()

# jalankan semua filter konvolusi
for name, kernel in kernels.items():
    result = convolution(gray, kernel)
    plt.figure(figsize=(4,4))
    plt.imshow(result, cmap='gray')
    plt.title(name)
    plt.axis("off")
    plt.show()
